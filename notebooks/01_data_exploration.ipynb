# %% [markdown]
# # 01 — Data Exploration
#
# Exploratory Data Analysis (EDA) on anti-spoofing audio datasets supported by this project:
# - ASVspoof 2019 (LA partition)
# - ASVspoof 5
# - In-The-Wild
# - Custom / synthetic samples

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display

from src.data.dataset_loader import DatasetLoader, DatasetType, Split
from src.data.audio_preprocessor import AudioPreprocessor
from src.data.feature_extractor import FeatureExtractor, FeatureType

# %%
# TODO: Set your dataset path here
DATASET_PATH = '../data/custom'

loader = DatasetLoader(
    dataset_type=DatasetType.CUSTOM,
    root_dir=DATASET_PATH,
).load()

print('Dataset distribution:', loader.class_distribution())

# %%
# Visualise a mel-spectrogram
preprocessor = AudioPreprocessor()
extractor = FeatureExtractor(feature_type=FeatureType.MEL_SPECTROGRAM)

# TODO: Replace with an actual audio file path
# import soundfile as sf
# waveform, sr = sf.read('path/to/audio.wav', dtype='float32', always_2d=False)
# waveform, sr = preprocessor.process(waveform, sr)
# feature = extractor.extract(waveform)
# plt.figure(figsize=(10, 4))
# librosa.display.specshow(feature[0], sr=sr, x_axis='time', y_axis='mel')
# plt.colorbar(format='%+2.0f dB')
# plt.title('Mel-Spectrogram')
# plt.tight_layout()
# plt.show()

print('Placeholder — add audio file path above to visualise')
